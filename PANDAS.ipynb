# %% [markdown]
# <a href="https://colab.research.google.com/github/oduoranto/Machine-Learning/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas - useful for data processing and analysis

# %%
import pandas as pd
import numpy as np

# %%
#Reads the csv file
game_df = pd.read_csv('/content/gaming_industry_trends.csv')

# %%
#Check the number of rowws and columns in the dataframe
game_df.shape
# Out:
# (1000, 11)

# %%
#Gives the information about each the dataframe
print(game_df.info)
# Out:
# <bound method DataFrame.info of                Game Title       Genre        Platform  Release Year  \
# 0            Neon Speed 5    Strategy            Xbox          2011
# 1           Cyber Quest 5     Shooter          Mobile          2018
# 2        Fantasy Rivals 1    Strategy            Xbox          2018
# 3    Warzone Chronicles 5      Horror            Xbox          2002
# 4           Cyber Quest 4         RPG              PC          2018
# ..                    ...         ...             ...           ...
# 995     Battle Warriors 1     Shooter  Cross-Platform          2006
# 996     Battle Warriors 4  Simulation     PlayStation          2016
# 997    Legends of Valor 3         RPG            Xbox          2020
# 998      Galaxy Raiders 4      Sports          Mobile          2015
# 999      Galaxy Raiders 1  Simulation     PlayStation          2016
#
#         Developer  Revenue (Millions $)  Players (Millions)  \
# ...

# %%
game_df.columns
# Out:
# Index(['Game Title', 'Genre', 'Platform', 'Release Year', 'Developer',
#        'Revenue (Millions $)', 'Players (Millions)', 'Peak Concurrent Players',
#        'Metacritic Score', 'Esports Popularity', 'Trending Status'],
#       dtype='object')

# %%
#Finding the missing values
game_df.isnull().sum()
# Out:
# Game Title                 0
# Genre                      0
# Platform                   0
# Release Year               0
# Developer                  0
# Revenue (Millions $)       0
# Players (Millions)         0
# Peak Concurrent Players    0
# Metacritic Score           0
# Esports Popularity         0
# Trending Status            0
# dtype: int64

# %%
game_df.value_counts('Developer')
# Out:
# Developer
# Sony            120
# Activision      109
# Rockstar        107
# Microsoft       106
# Ubisoft         103
# Capcom           96
# Nintendo         96
# EA               92
# Square Enix      88
# Bandai Namco     83
# Name: count, dtype: int64

# %%
game_df.value_counts('Genre')
# Out:
# Genre
# Action        122
# Sports        116
# Strategy      116
# Fighting      103
# Shooter       100
# Horror         96
# Racing         95
# Adventure      87
# Simulation     87
# RPG            78
# Name: count, dtype: int64

# %%
game_df.describe()
# Out:
#        Release Year  Revenue (Millions $)  Players (Millions)  \
# count   1000.000000           1000.000000         1000.000000
# mean    2012.074000           2483.017800          103.499820
# std        7.031356           1412.629451           58.869562
# min     2000.000000             11.430000            0.530000
# 25%     2006.000000           1276.190000           52.005000
# 50%     2012.000000           2476.130000          107.040000
# 75%     2018.000000           3677.797500          155.632500
# max     2024.000000           4999.790000          199.980000
#
#        Peak Concurrent Players  Metacritic Score
# count              1000.000000       1000.000000
# mean                 31.602150         74.990000
# std                  23.023375         14.618536
# min                   0.110000         50.000000
# 25%                  12.967500         62.000000
# 50%                  26.405000         76.000000
# 75%                  46.020000         87.000000
# ...

# %%
game_df.drop(index=0, axis=0)
# Out:
#                Game Title       Genre        Platform  Release Year  \
# 1           Cyber Quest 5     Shooter          Mobile          2018
# 2        Fantasy Rivals 1    Strategy            Xbox          2018
# 3    Warzone Chronicles 5      Horror            Xbox          2002
# 4           Cyber Quest 4         RPG              PC          2018
# 5    Warzone Chronicles 3      Sports          Mobile          2022
# ..                    ...         ...             ...           ...
# 995     Battle Warriors 1     Shooter  Cross-Platform          2006
# 996     Battle Warriors 4  Simulation     PlayStation          2016
# 997    Legends of Valor 3         RPG            Xbox          2020
# 998      Galaxy Raiders 4      Sports          Mobile          2015
# 999      Galaxy Raiders 1  Simulation     PlayStation          2016
#
#         Developer  Revenue (Millions $)  Players (Millions)  \
# 1    Bandai Namco               4345.97               65.28
# ...

# %%
game_df.drop(columns='Trending Status', axis=1)
# Out:
#                Game Title       Genre        Platform  Release Year  \
# 0            Neon Speed 5    Strategy            Xbox          2011
# 1           Cyber Quest 5     Shooter          Mobile          2018
# 2        Fantasy Rivals 1    Strategy            Xbox          2018
# 3    Warzone Chronicles 5      Horror            Xbox          2002
# 4           Cyber Quest 4         RPG              PC          2018
# ..                    ...         ...             ...           ...
# 995     Battle Warriors 1     Shooter  Cross-Platform          2006
# 996     Battle Warriors 4  Simulation     PlayStation          2016
# 997    Legends of Valor 3         RPG            Xbox          2020
# 998      Galaxy Raiders 4      Sports          Mobile          2015
# 999      Galaxy Raiders 1  Simulation     PlayStation          2016
#
#         Developer  Revenue (Millions $)  Players (Millions)  \
# 0          Capcom                 52.28               77.99
# ...

# %%
game_df['Trending Status'] = game_df['Trending Status'].fillna(0)
print(game_df.columns)
# Out:
# Index(['Game Title', 'Genre', 'Platform', 'Release Year', 'Developer',
#        'Revenue (Millions $)', 'Players (Millions)', 'Peak Concurrent Players',
#        'Metacritic Score', 'Esports Popularity', 'Trending Status'],
#       dtype='object')
